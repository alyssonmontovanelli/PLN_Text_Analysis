# %% [markdown]
# # <font color = 'red'> Análise Exploratória Inicial </font>
#
# ### <font color = 'red'> Foco em entender melho a estrutura dos dados e escolher a empresa e problema de negócio </font>

# %%
# Imports

import os
import numpy as np
import pandas as pd

# %%
# Visualizando Cj dados
dados = pd.read_csv('/Projetos Pessoais/DataScience/PLN_Text_Analysis/data/dados_brutos.csv',
                       sep =',')

# %%
dados.head(20)
# Out:
#                         Empresa  \
# 0                         Cemig
# 1                         Cemig
# 2                         Cemig
# 3   Equatorial Maranhão (CEMAR)
# 4                         Cemig
# 5                         Cemig
# 6                         Cemig
# 7                         Cemig
# 8                         Cemig
# 9             Vivo - Telefônica
# 10  Equatorial Maranhão (CEMAR)
# 11                        iFood
# 12                        iFood
# 13                        Cemig
# 14                        Cemig
# 15                        Cemig
# 16                        Cemig
# 17                        Cemig
# 18                        Cemig
# 19                   SPC Brasil
#
#                                                Relato
# 0   Preciso do formulário para análise de carga ru...
# 1   De que maneira será realizado o recadastrament...
# 2   Qual é a bandeira tarifária em vigor atualment...
# 3   Cadastro de tarifa social. NIS: XXX.XXX.XXX-XX...
# ...

# %%
dados.Empresa.value_counts().reset_index().head(10)
# Out:
#                 Empresa  count
# 0       Serasa Experian    440
# 1  Latam Airlines (Tam)    360
# 2     Vivo - Telefônica    302
# 3    Azul Linhas Aéreas    260
# 4                Google    223
# 5                Nubank    222
# 6                   Tim    211
# 7         Claro Celular    210
# 8       Banco do Brasil    203
# 9   Hurb - Hotel Urbano    180

# %%
dados.shape
# Out:
# (8330, 2)

# %%
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8330 entries, 0 to 8329
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Empresa  8330 non-null   object
#  1   Relato   8330 non-null   object
# dtypes: object(2)
# memory usage: 130.3+ KB
